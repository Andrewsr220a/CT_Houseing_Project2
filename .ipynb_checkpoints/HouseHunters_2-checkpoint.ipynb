# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
#Loading csv files

state_prices_file = "Sale_Prices_State.csv"
city_prices_file = "Sale_Prices_City.csv"
city_prices_2_file = "Sale_Prices_City 2.csv"

# %%
state_prices_df = pd.read_csv(state_prices_file)
state_prices_df.head()
# Out:
#    Unnamed: 0  RegionID  RegionName  SizeRank   2008-03   2008-04   2008-05  \
# 0           0         9  California         1  392500.0  373800.0  351800.0
# 1           1        54       Texas         2  139900.0  139300.0  137600.0
# 2           2        43    New York         3       NaN       NaN       NaN
# 3           3        14     Florida         4  203400.0  195500.0  189300.0
# 4           4        21    Illinois         5  204400.0  198400.0  185000.0
#
#     2008-06   2008-07   2008-08  ...  2019-06  2019-07  2019-08  2019-09  \
# 0  334700.0  320100.0  306600.0  ...   493000   491900   491600   493800
# 1  137400.0  137700.0  139500.0  ...   226100   226700   228100   229400
# 2       NaN       NaN       NaN  ...   297000   298100   301700   295100
# 3  184800.0  181700.0  178100.0  ...   224600   226100   227000   228900
# 4  177500.0  174300.0  176300.0  ...   195900   192000   189500   188100
#
#    2019-10  2019-11  2019-12  2020-01  2020-02   2020-03
# ...

# %%
#State 2 data from 2018 - 2020

#state_prices_2018_df  = state_prices_df.loc[:, ['RegionID', 'RegionName', 'SizeRank',"2018-01",'2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12','2020-01','2020-02','2020-03']].head()
state_prices_2018_df  = state_prices_df.loc[:, ['RegionID', 'RegionName', 'SizeRank',"2018-01",'2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12','2020-01','2020-02','2020-03']]

state_prices_2018_df.rename(columns = {'RegionName':'State'}, inplace = True)
state_prices_2018_df
# Out:
#     RegionID                 State  SizeRank  2018-01  2018-02  2018-03  \
# 0          9            California         1   469200   472300   476400
# 1         54                 Texas         2   210200   212500   214100
# 2         43              New York         3   266300   268500   273300
# 3         14               Florida         4   206500   211800   215800
# 4         21              Illinois         5   175900   178800   183400
# 5         47          Pennsylvania         6   159000   159400   162900
# 6         44                  Ohio         7   133300   135900   136200
# 7         30              Michigan         8   143900   146100   147400
# 8         16               Georgia         9   174800   177800   178700
# 9         36        North Carolina        10   183200   187200   191200
# 10        40            New Jersey        11   266600   267000   268400
# 11        56              Virginia        12   254500   255300   257000
# ...

# %%
print(len(state_prices_2018_df))
# Out:
# 49

# %%
state_prices_2018_small_df = state_prices_2018_df.loc[:, ['RegionID', 'State', 'SizeRank','2018-01','2018-02']]

# %%
state_prices_2018_small_df
# Out:
#     RegionID                 State  SizeRank  2018-01  2018-02
# 0          9            California         1   469200   472300
# 1         54                 Texas         2   210200   212500
# 2         43              New York         3   266300   268500
# 3         14               Florida         4   206500   211800
# 4         21              Illinois         5   175900   178800
# 5         47          Pennsylvania         6   159000   159400
# 6         44                  Ohio         7   133300   135900
# 7         30              Michigan         8   143900   146100
# 8         16               Georgia         9   174800   177800
# 9         36        North Carolina        10   183200   187200
# 10        40            New Jersey        11   266600   267000
# 11        56              Virginia        12   254500   255300
# 12        59            Washington        13   335800   340700
# 13        26         Massachusetts        14   356200   365800
# ...

# %%
list_state_month=[]
list_state_year=[]
list_state_sale=[]
var1=len(state_prices_2018_small_df.columns)-3
i=4
#print(len(state_prices_2018_small_df.columns))
for index in range(len(state_prices_2018_small_df)):
        print(state_prices_2018_small_df.iloc[index])
    #print(state_prices_2018_df)
#     for i in range(5):
#        list_state_sale.append(state_prices_2018_small_df.iloc[3,(3+i)])
#         list_state_month.append(i)
#         list_state_year.append('2018')
#       print(state_prices_2018_small_df.iloc[index,(i)])
    #print(state_prices_2018_df.iloc[index,3])
# Out:
# RegionID             9
# State       California
# SizeRank             1
# 2018-01         469200
# 2018-02         472300
# Name: 0, dtype: object
# RegionID        54
# State        Texas
# SizeRank         2
# 2018-01     210200
# 2018-02     212500
# Name: 1, dtype: object
# RegionID          43
# State       New York
# SizeRank           3
# 2018-01       266300
# 2018-02       268500
# Name: 2, dtype: object
# RegionID         14
# State       Florida
# SizeRank          4
# 2018-01      206500
# 2018-02      211800
# Name: 3, dtype: object
# RegionID          21
# State       Illinois
# SizeRank           5
# 2018-01       175900
# 2018-02       178800
# Name: 4, dtype: object
# RegionID              47
# State       Pennsylvania
# SizeRank               6
# 2018-01           159000
# 2018-02           159400
# Name: 5, dtype: object
# RegionID        44
# State         Ohio
# SizeRank         7
# 2018-01     133300
# 2018-02     135900
# Name: 6, dtype: object
# ...

# %%
# add new column with average sale for each state
state_prices_2018_df['Average Sale'] = state_prices_2018_df.mean(axis=1)
# display the dataframe
state_prices_2018_df
# Out:
#    RegionID       State  SizeRank  2018-01  2018-02  2018-03  2018-04  \
# 0         9  California         1   469200   472300   476400   479200
# 1        54       Texas         2   210200   212500   214100   215300
# 2        43    New York         3   266300   268500   273300   280500
# 3        14     Florida         4   206500   211800   215800   217700
# 4        21    Illinois         5   175900   178800   183400   184600
#
#    2018-05  2018-06  2018-07  ...  2019-07  2019-08  2019-09  2019-10  \
# 0   480800   482300   483600  ...   491900   491600   493800   498400
# 1   215300   215500   215300  ...   226700   228100   229400   232700
# 2   282000   283200   282800  ...   298100   301700   295100   296000
# 3   215900   215100   214900  ...   226100   227000   228900   230800
# 4   183400   184900   185400  ...   192000   189500   188100   190000
#
#    2019-11  2019-12  2020-01  2020-02   2020-03   Average Sale
# ...

# %%
#State 2 data for 2019

state_prices_2019_df  = state_prices_df.loc[:, ['RegionID', 'RegionName', 'SizeRank','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12']].head()
state_prices_2019_df.rename(columns = {'RegionName':'State'}, inplace = True)
state_prices_2019_df
# Out:
#    RegionID       State  SizeRank  2019-01  2019-02  2019-03  2019-04  \
# 0         9  California         1   485900   488400   489900   493200
# 1        54       Texas         2   217800   219100   220500   223300
# 2        43    New York         3   290200   289700   285700   287900
# 3        14     Florida         4   224600   225800   225300   224400
# 4        21    Illinois         5   184200   188500   195700   199000
#
#    2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 0   492200   493000   491900   491600   493800   498400   505600   513500
# 1   224700   226100   226700   228100   229400   232700   234700   236800
# 2   287500   297000   298100   301700   295100   296000   297100   305400
# 3   223800   224600   226100   227000   228900   230800   234400   238100
# 4   198700   195900   192000   189500   188100   190000   191300   194600

# %%
# add new column with average sale for each state
#state_prices_2019_df['Average Sale'] = state_prices_2019_df.mean(axis=1)
state_prices_2019_df['Average Sale']  = state_prices_2019_df[['2019-01', '2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12']].mean(axis=1)
# display the dataframe
state_prices_2019_df
# Out:
#    RegionID       State  SizeRank  2019-01  2019-02  2019-03  2019-04  \
# 0         9  California         1   485900   488400   489900   493200
# 1        54       Texas         2   217800   219100   220500   223300
# 2        43    New York         3   290200   289700   285700   287900
# 3        14     Florida         4   224600   225800   225300   224400
# 4        21    Illinois         5   184200   188500   195700   199000
#
#    2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12  \
# 0   492200   493000   491900   491600   493800   498400   505600   513500
# 1   224700   226100   226700   228100   229400   232700   234700   236800
# 2   287500   297000   298100   301700   295100   296000   297100   305400
# 3   223800   224600   226100   227000   228900   230800   234400   238100
# 4   198700   195900   192000   189500   188100   190000   191300   194600
#
#     Average Sale
# 0  494783.333333
# 1  226658.333333
# 2  294283.333333
# 3  227816.666667
# ...

# %%
city_prices_df = pd.read_csv(city_prices_file)
city_prices_df.head()
# Out:
#    Unnamed: 0  RegionID   RegionName   StateName  SizeRank   2008-03  \
# 0           0      6181     New York    New York         1       NaN
# 1           1     12447  Los Angeles  California         2  507600.0
# 2           2     39051      Houston       Texas         3  138400.0
# 3           3     17426      Chicago    Illinois         4  325100.0
# 4           4      6915  San Antonio       Texas         5  130900.0
#
#     2008-04   2008-05   2008-06   2008-07  ...   2019-06   2019-07   2019-08  \
# 0       NaN       NaN       NaN       NaN  ...  563200.0  570500.0  572800.0
# 1  489600.0  463000.0  453100.0  438100.0  ...  706800.0  711800.0  717300.0
# 2  135500.0  132200.0  131000.0  133400.0  ...  209700.0  207400.0  207600.0
# 3  314800.0  286900.0  274600.0  268500.0  ...  271500.0  266500.0  264900.0
# 4  131300.0  131200.0  131500.0  131600.0  ...  197100.0  198700.0  200200.0
#
#     2019-09   2019-10   2019-11   2019-12   2020-01   2020-02   2020-03
# ...

# %%
#City data from 2018- 2020 df

city_prices_2018_df = city_prices_df.loc[:, ['RegionID', 'RegionName', 'StateName', 'SizeRank',"2018-01",'2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12','2020-01','2020-02','2020-03']].head()
city_prices_2018_df
# Out:
#    RegionID   RegionName   StateName  SizeRank   2018-01   2018-02  2018-03  \
# 0      6181     New York    New York         1  555000.0  553200.0   559400
# 1     12447  Los Angeles  California         2  611000.0  616800.0   624000
# 2     39051      Houston       Texas         3  192700.0  195200.0   196300
# 3     17426      Chicago    Illinois         4  230400.0  238500.0   247400
# 4      6915  San Antonio       Texas         5  185600.0  185700.0   185400
#
#    2018-04  2018-05  2018-06  ...   2019-06   2019-07   2019-08   2019-09  \
# 0   555700   556300   547000  ...  563200.0  570500.0  572800.0  569900.0
# 1   631300   629100   635300  ...  706800.0  711800.0  717300.0  714100.0
# 2   197800   195500   194300  ...  209700.0  207400.0  207600.0  207000.0
# 3   250000   244600   242100  ...  271500.0  266500.0  264900.0  265000.0
# 4   186000   187300   186800  ...  197100.0  198700.0  200200.0  200800.0
#
#     2019-10   2019-11   2019-12   2020-01   2020-02   2020-03
# ...

# %%
city_prices_2_df = pd.read_csv(city_prices_2_file)
city_prices_2_df.head()
# Out:
#    Unnamed: 0  RegionID   RegionName   StateName  SizeRank   2008-03  \
# 0           0      6181     New York    New York         1       NaN
# 1           1     12447  Los Angeles  California         2  507600.0
# 2           2     39051      Houston       Texas         3  138400.0
# 3           3     17426      Chicago    Illinois         4  325100.0
# 4           4      6915  San Antonio       Texas         5  130900.0
#
#     2008-04   2008-05   2008-06   2008-07  ...   2019-06   2019-07   2019-08  \
# 0       NaN       NaN       NaN       NaN  ...  563200.0  570500.0  572800.0
# 1  489600.0  463000.0  453100.0  438100.0  ...  706800.0  711800.0  717300.0
# 2  135500.0  132200.0  131000.0  133400.0  ...  209700.0  207400.0  207600.0
# 3  314800.0  286900.0  274600.0  268500.0  ...  271500.0  266500.0  264900.0
# 4  131300.0  131200.0  131500.0  131600.0  ...  197100.0  198700.0  200200.0
#
#     2019-09   2019-10   2019-11   2019-12   2020-01   2020-02   2020-03
# ...

# %%
#City 2 data from 2018- 2020 df

city_prices_2_2018_df = city_prices_2_df.loc[:, ['RegionID', 'RegionName', 'StateName', 'SizeRank',"2018-01",'2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12','2020-01','2020-02','2020-03']].head()
city_prices_2_2018_df
# Out:
#    RegionID   RegionName   StateName  SizeRank   2018-01   2018-02  2018-03  \
# 0      6181     New York    New York         1  555000.0  553200.0   559400
# 1     12447  Los Angeles  California         2  611000.0  616800.0   624000
# 2     39051      Houston       Texas         3  192700.0  195200.0   196300
# 3     17426      Chicago    Illinois         4  230400.0  238500.0   247400
# 4      6915  San Antonio       Texas         5  185600.0  185700.0   185400
#
#    2018-04  2018-05  2018-06  ...   2019-06   2019-07   2019-08   2019-09  \
# 0   555700   556300   547000  ...  563200.0  570500.0  572800.0  569900.0
# 1   631300   629100   635300  ...  706800.0  711800.0  717300.0  714100.0
# 2   197800   195500   194300  ...  209700.0  207400.0  207600.0  207000.0
# 3   250000   244600   242100  ...  271500.0  266500.0  264900.0  265000.0
# 4   186000   187300   186800  ...  197100.0  198700.0  200200.0  200800.0
#
#     2019-10   2019-11   2019-12   2020-01   2020-02   2020-03
# ...

# %%
# add new column with average sale for each region of the state
city_prices_2_2018_df['Average City Sale'] = city_prices_2_2018_df.mean(axis=1)
# display the dataframe
city_prices_2_2018_df
# Out:
#    RegionID   RegionName   StateName  SizeRank   2018-01   2018-02  2018-03  \
# 0      6181     New York    New York         1  555000.0  553200.0   559400
# 1     12447  Los Angeles  California         2  611000.0  616800.0   624000
# 2     39051      Houston       Texas         3  192700.0  195200.0   196300
# 3     17426      Chicago    Illinois         4  230400.0  238500.0   247400
# 4      6915  San Antonio       Texas         5  185600.0  185700.0   185400
#
#    2018-04  2018-05  2018-06  ...   2019-07   2019-08   2019-09   2019-10  \
# 0   555700   556300   547000  ...  570500.0  572800.0  569900.0  560800.0
# 1   631300   629100   635300  ...  711800.0  717300.0  714100.0  711900.0
# 2   197800   195500   194300  ...  207400.0  207600.0  207000.0  211400.0
# 3   250000   244600   242100  ...  266500.0  264900.0  265000.0  264100.0
# 4   186000   187300   186800  ...  198700.0  200200.0  200800.0  203400.0
#
# ...

# %%
#City 2 data from 2019 df

city_prices_2_2019_df = city_prices_2_df.loc[:, ['RegionID', 'RegionName', 'StateName', 'SizeRank','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12']].head()
city_prices_2_2019_df.rename(columns = {'StateName':'State'}, inplace = True)
city_prices_2_2019_df
# Out:
#    RegionID   RegionName       State  SizeRank  2019-01  2019-02  2019-03  \
# 0      6181     New York    New York         1   557700   561100   560100
# 1     12447  Los Angeles  California         2   680800   684300   699200
# 2     39051      Houston       Texas         3   206600   205100   206800
# 3     17426      Chicago    Illinois         4   245700   263200   290800
# 4      6915  San Antonio       Texas         5   190400   189600   191200
#
#     2019-04   2019-05   2019-06   2019-07   2019-08   2019-09   2019-10  \
# 0  571000.0  559800.0  563200.0  570500.0  572800.0  569900.0  560800.0
# 1  702700.0  703800.0  706800.0  711800.0  717300.0  714100.0  711900.0
# 2  206200.0  210100.0  209700.0  207400.0  207600.0  207000.0  211400.0
# 3  292000.0  276000.0  271500.0  266500.0  264900.0  265000.0  264100.0
# 4  193300.0  196000.0  197100.0  198700.0  200200.0  200800.0  203400.0
#
#     2019-11   2019-12
# 0  571500.0  575100.0
# 1  718400.0  727100.0
# ...

# %%
# add new column with average sale for each region of the state
city_prices_2_2019_df['Average City Sale']  = city_prices_2_df[['2019-01', '2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12']].mean(axis=1)
# display the dataframe
city_prices_2_2019_df
# Out:
#    RegionID   RegionName       State  SizeRank  2019-01  2019-02  2019-03  \
# 0      6181     New York    New York         1   557700   561100   560100
# 1     12447  Los Angeles  California         2   680800   684300   699200
# 2     39051      Houston       Texas         3   206600   205100   206800
# 3     17426      Chicago    Illinois         4   245700   263200   290800
# 4      6915  San Antonio       Texas         5   190400   189600   191200
#
#     2019-04   2019-05   2019-06   2019-07   2019-08   2019-09   2019-10  \
# 0  571000.0  559800.0  563200.0  570500.0  572800.0  569900.0  560800.0
# 1  702700.0  703800.0  706800.0  711800.0  717300.0  714100.0  711900.0
# 2  206200.0  210100.0  209700.0  207400.0  207600.0  207000.0  211400.0
# 3  292000.0  276000.0  271500.0  266500.0  264900.0  265000.0  264100.0
# 4  193300.0  196000.0  197100.0  198700.0  200200.0  200800.0  203400.0
#
#     2019-11   2019-12  Average City Sale
# 0  571500.0  575100.0      566125.000000
# ...

# %%
#checking for any duplicates in df(s)

any(state_prices_2019_df.duplicated())
# Out:
# False

# %%
any(city_prices_2018_df.duplicated())
# Out:
# False

# %%
any(city_prices_2_2019_df.duplicated())
# Out:
# False

# %% [markdown]
# Create Database Connection

# %%
connection_string = "postgres:postgres@localhost:5432/StateCityHousingPrice_db"
engine = create_engine(f'postgresql://{connection_string}')
